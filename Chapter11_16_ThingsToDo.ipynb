# %%
def hours():
    print("Open 9-5 daily")

# %% [markdown]
# ## 11.1
#
# Create a file called `zoo.py` with a function named `hours()` that prints the zoo's hours. Import the module and call the function.

# %%
import importlib
import zoo

importlib.reload(zoo)

zoo.hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# ## 11.2
#
# Import the `zoo` module as `menagerie` and call its `hours()` function.

# %%
import zoo as menagerie

menagerie.hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# ## 16.4
#
# Use the `sqlite3` module to create a SQLite database called `books.db` and a table called `books` with the fields:
#
# - title (TEXT)
# - author (TEXT)
# - year (INTEGER)

# %%
import sqlite3

conn = sqlite3.connect("books.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS books (
    title TEXT,
    author TEXT,
    year INTEGER
)
""")

conn.commit()

print("books.db and books table created.")
# Out:
# books.db and books table created.

# %% [markdown]
# ## 16.5
#
# Read `books2.csv` and insert its data into the `books` table.

# %%
csv_text = """title,author,year
The Weirdstone of Brisingamen,Alan Garner,1960
Perdido Street Station,China Miéville,2000
Thud!,Terry Pratchett,2005
The Spellman Files,Lisa Lutz,2007
Small Gods,Terry Pratchett,1992
"""

with open("books2.csv", "w", encoding="utf-8") as file:
    file.write(csv_text)

print("books2.csv created.")
# Out:
# books2.csv created.

# %%
import csv
import sqlite3

conn = sqlite3.connect("books.db")
cursor = conn.cursor()

with open("books2.csv", "r", encoding="utf-8") as file:
    books = csv.DictReader(file)

    for book in books:
        cursor.execute(
            "INSERT INTO books (title, author, year) VALUES (?, ?, ?)",
            (book["title"], book["author"], int(book["year"]))
        )

conn.commit()
conn.close()

print("Data inserted into books table.")
# Out:
# Data inserted into books table.

# %% [markdown]
# ## 16.8
#
# Use the `sqlalchemy` module to connect to the `books.db` database and display the book titles in alphabetical order.

# %%
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///books.db")

with engine.connect() as connection:
    result = connection.execute(
        text("SELECT title FROM books ORDER BY title")
    )

    for row in result:
        print(row[0])
# Out:
# Perdido Street Station
# Perdido Street Station
# Small Gods
# Small Gods
# The Spellman Files
# The Spellman Files
# The Weirdstone of Brisingamen
# The Weirdstone of Brisingamen
# Thud!
# Thud!
